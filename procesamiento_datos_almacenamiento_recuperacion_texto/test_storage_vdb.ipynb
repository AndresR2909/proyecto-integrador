# %%
#pip install azure-functions azure-functions-durable pandas azure-storage-blob azure-functions python-dotenv langchain-openai langchain pinecone-client pyarrow adlfs fsspec langchain_pinecone azure-storage-file-datalake -q

# %%
#pip freeze ->requirements.txt

# %%
import azure.functions as func
import logging
from datetime import datetime
import os

from external.blob_storage import BlobStorage
from external.data_lake_pandas import DataLakePandas
from external.data_lake_storage import DataLakeStorage

from app.repositories.pandas_loader import DataLakeLoader
from app.repositories.blob_storage_reader import BlobStorageReader
from app.repositories.pandas_reader import DataLakeReader

from app.use_cases.data_prep_delta_curated import DataPreprocessingDeltaCurated
from app.use_cases.data_prep_delta_raw import DataPreprocessingDeltaRaw 

from dotenv import load_dotenv
load_dotenv()


DELTA_DAYS = os.environ.get('DELTA_DAYS')
DELTA_HOURS = os.environ.get('DELTA_HOURS')
SCHEDULE = os.environ.get('CRON_SCHEDULE')

bp1 = func.Blueprint()
container_name = "landing"
blob_storage = BlobStorage(container_name)
bs_reader = BlobStorageReader(blob_storage)
dl_pandas = DataLakePandas()
dl_loader = DataLakeLoader(dl_pandas)

dl_storage = DataLakeStorage("raw")
dl_reader = DataLakeReader(dl_pandas,dl_storage)

use_case_delta_raw = DataPreprocessingDeltaRaw(bs_reader, dl_loader, dl_reader)  

use_case_delta_curated = DataPreprocessingDeltaCurated(dl_reader, dl_loader)  


timestamp = datetime.now()
filter_date = timestamp.strftime('%Y-%m-%d')
try:
    container_source = "landing"
    container_sink = "raw"
    filename= "data_from_youtube"
    filter = None
    delta_day= int(DELTA_DAYS)
    delta_hour= int(DELTA_HOURS)
    df_raw = use_case_delta_raw.execute(container_source, 
                            container_sink,
                            filename,
                            delta_day=delta_day,
                            delta_hour= delta_hour
                            )
    logging.info('external to raw')
    print('external to raw')
    container_source = "raw"
    container_sink = "curated"
    filename= "data_from_youtube"
    filter = None
    df_curated = use_case_delta_curated.execute(container_source, 
                                                container_sink,
                                                filename,
                                                delta_day,
                                                delta_hour, 
                                                filter)
    logging.info('raw to curated')
    print('raw to curated')
except Exception as e:
    msn = f'Error {e} , ejecutando la etl'
    logging.info(msn)
    print(msn)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   chanel_name       3 non-null      object
#  1   chanel_id         3 non-null      object
#  2   chanel_url        3 non-null      object
#  3   video_id          3 non-null      object
#  4   title             3 non-null      object
#  5   url               3 non-null      object
#  6   keywords          3 non-null      object
#  7   publish_date      3 non-null      object
#  8   relativeDateText  3 non-null      object
#  9   total_length      3 non-null      int64
#  10  total_views       3 non-null      int64
#  11  video_rating      0 non-null      float64
#  12  description       3 non-null      object
#  13  duration          3 non-null      int64
#  14  caption_text_es   3 non-null      object
# dtypes: float64(1), int64(3), object(11)
# memory usage: 492.0+ bytes
# [2024]
# abfs://sadatalakeproyecto.dfs.core.windows.net/raw/data_from_youtube/data_from_youtube_2024
# external to raw
# hoy 2024-06-12 22:43:05.581849
# c:\Users\felip\Desktop\2024\MAESTRIA\proyecto\az-function-durable\app\use_cases\data_prep_delta_curated.py:65: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean["caption_text_es"] = df_clean["clean_title"] + ". " + df_clean["caption_text_es"].fillna(' ')
# c:\Users\felip\Desktop\2024\MAESTRIA\proyecto\az-function-durable\app\use_cases\data_prep_delta_curated.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['text']= df_clean["caption_text_es"].apply(self._limpiar_texto)
# [2024]
# abfs://sadatalakeproyecto.dfs.core.windows.net/curated/data_from_youtube/data_from_youtube_2024
# raw to curated

# %%
df_curated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 160 entries, 0 to 191
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   chanel_name       160 non-null    object
#  1   video_id          160 non-null    object
#  2   source            160 non-null    object
#  3   publish_date      160 non-null    object
#  4   duration          160 non-null    int64
#  5   last_update_date  160 non-null    object
#  6   title             160 non-null    object
#  7   text              160 non-null    object
#  8   year              160 non-null    int64
# dtypes: int64(2), object(7)
# memory usage: 12.5+ KB

# %%
df_curated[df_curated['publish_date']>='2024-06-01']
# Out:
#              chanel_name     video_id  \
# 141           Bolsas hoy  oTJiyKjgHw8
# 143    USACRYPTONOTICIAS  bQy-w0DoZYk
# 144           Bolsas hoy  1d3ErwzUHbM
# 145          Bitcoin hoy  5gIUZMVDaLg
# 146           Bolsas hoy  iOrr045IQf4
# 147          Bitcoin hoy  w6_2TQAS__4
# 148    USACRYPTONOTICIAS  s_7kVTuWFuo
# 150          Bitcoin hoy  7TKDKPPb9Js
# 151           Bolsas hoy  kcVChaXvQhw
# 152           Bolsas hoy  mUhQEpHl0DA
# 153    USACRYPTONOTICIAS  NTb8gRdI2Ls
# 154  Memorias de Tiburón  SeSShFo1YpQ
# 155    USACRYPTONOTICIAS  FyVFucL2Pe4
# 156          Bitcoin hoy  WxzkSXxAIK0
# 157           Bolsas hoy  ZEEmHT2FhnI
# 158          ARENA ALFA   67rfAw0mNQM
# 159           Bolsas hoy  dmIx2DzFGyQ
# 160    USACRYPTONOTICIAS  aWAlSAZmZ7k
# 162           Bolsas hoy  ATc1wGWgEJc
# 163          Bitcoin hoy  Pev8We1S2Qk
# 165    USACRYPTONOTICIAS  pJ__Ft5ESz0
# 166          Bitcoin hoy  nJ-tFqZvzSc
# 167           Bolsas hoy  v39KrUYRdjI
# 168           Bolsas hoy  SHLFHMTti8E
# 169          Bitcoin hoy  eRDLKqY3b_k
# 170    USACRYPTONOTICIAS  dpKPtlSp444
# 172           Bolsas hoy  RW5sxrJHeAk
# 173          Bitcoin hoy  16z6MuIXkCE
# 176           Bolsas hoy  2yZ3GZp02cI
# 177          Bitcoin hoy  CGS3R5BoWCU
# 178    USACRYPTONOTICIAS  Jtr8vN3-jVw
# 180           Bolsas hoy  ILnBnLIiC7M
# 181          Bitcoin hoy  sW2ufWXhHnE
# 182           Bolsas hoy  CPZCc6yTyx0
# 183          Bitcoin hoy  G3V-xf0VIO4
# 185  Memorias de Tiburón  k9AX7cS_7m0
# 186    USACRYPTONOTICIAS  _-5jLaWKv5w
# 187           Bolsas hoy  Bk4HfHQ0C78
# 188          Bitcoin hoy  18eS0DT6gU8
# 189           Bolsas hoy  f9erkHImeJc
# 191    USACRYPTONOTICIAS  023UgEEl5Aw
#
#                                           source publish_date  duration  \
# 141  https://www.youtube.com/watch?v=oTJiyKjgHw8   2024-06-01      4205
# 143  https://www.youtube.com/watch?v=bQy-w0DoZYk   2024-06-02      6791
# 144  https://www.youtube.com/watch?v=1d3ErwzUHbM   2024-06-03       877
# 145  https://www.youtube.com/watch?v=5gIUZMVDaLg   2024-06-02      1100
# 146  https://www.youtube.com/watch?v=iOrr045IQf4   2024-06-03      1416
# 147  https://www.youtube.com/watch?v=w6_2TQAS__4   2024-06-03       677
# 148  https://www.youtube.com/watch?v=s_7kVTuWFuo   2024-06-03      6827
# 150  https://www.youtube.com/watch?v=7TKDKPPb9Js   2024-06-04      1159
# 151  https://www.youtube.com/watch?v=kcVChaXvQhw   2024-06-04       630
# 152  https://www.youtube.com/watch?v=mUhQEpHl0DA   2024-06-04      1233
# 153  https://www.youtube.com/watch?v=NTb8gRdI2Ls   2024-06-04      6922
# 154  https://www.youtube.com/watch?v=SeSShFo1YpQ   2024-06-04       687
# 155  https://www.youtube.com/watch?v=FyVFucL2Pe4   2024-06-04       464
# 156  https://www.youtube.com/watch?v=WxzkSXxAIK0   2024-06-05      1128
# 157  https://www.youtube.com/watch?v=ZEEmHT2FhnI   2024-06-05       622
# 158  https://www.youtube.com/watch?v=67rfAw0mNQM   2024-06-05       706
# 159  https://www.youtube.com/watch?v=dmIx2DzFGyQ   2024-06-05      1334
# 160  https://www.youtube.com/watch?v=aWAlSAZmZ7k   2024-06-05      7661
# 162  https://www.youtube.com/watch?v=ATc1wGWgEJc   2024-06-06      1401
# 163  https://www.youtube.com/watch?v=Pev8We1S2Qk   2024-06-05       691
# 165  https://www.youtube.com/watch?v=pJ__Ft5ESz0   2024-06-06      3851
# 166  https://www.youtube.com/watch?v=nJ-tFqZvzSc   2024-06-06       936
# 167  https://www.youtube.com/watch?v=v39KrUYRdjI   2024-06-07      1128
# 168  https://www.youtube.com/watch?v=SHLFHMTti8E   2024-06-07       685
# 169  https://www.youtube.com/watch?v=eRDLKqY3b_k   2024-06-07       696
# 170  https://www.youtube.com/watch?v=dpKPtlSp444   2024-06-07      7460
# 172  https://www.youtube.com/watch?v=RW5sxrJHeAk   2024-06-08      3250
# 173  https://www.youtube.com/watch?v=16z6MuIXkCE   2024-06-08       383
# 176  https://www.youtube.com/watch?v=2yZ3GZp02cI   2024-06-10      1227
# 177  https://www.youtube.com/watch?v=CGS3R5BoWCU   2024-06-10       818
# 178  https://www.youtube.com/watch?v=Jtr8vN3-jVw   2024-06-10       757
# 180  https://www.youtube.com/watch?v=ILnBnLIiC7M   2024-06-11       981
# 181  https://www.youtube.com/watch?v=sW2ufWXhHnE   2024-06-10      1285
# 182  https://www.youtube.com/watch?v=CPZCc6yTyx0   2024-06-11      1444
# 183  https://www.youtube.com/watch?v=G3V-xf0VIO4   2024-06-11       789
# 185  https://www.youtube.com/watch?v=k9AX7cS_7m0   2024-06-11       604
# 186  https://www.youtube.com/watch?v=_-5jLaWKv5w   2024-06-11      3610
# 187  https://www.youtube.com/watch?v=Bk4HfHQ0C78   2024-06-11      1179
# 188  https://www.youtube.com/watch?v=18eS0DT6gU8   2024-06-11       812
# 189  https://www.youtube.com/watch?v=f9erkHImeJc   2024-06-12      1169
# 191  https://www.youtube.com/watch?v=023UgEEl5Aw   2024-06-12      4586
#
#     last_update_date                                              title  \
# 141       2024-06-01  en qué invertir desde junio en las bolsas prem...
# 143       2024-06-02  bitcoin: te concentras o pierdes el último coh...
# 144       2024-06-03  bolsas hoy: amd presentó nuevo procesador ia p...
# 145       2024-06-03  qué hará bitcoin hoy  03/06/24 08:00 análisis ...
# 146       2024-06-03  junio primera confirmación vendedora ¡qué pode...
# 147       2024-06-03  ruido y trampas hoy qué esperamos de bitcoin c...
# 148       2024-06-03  bitcoin: camino al matadero | btc | cryptos | ...
# 150       2024-06-04  qué hará bitcoin hoy  04/06/24 08:00 análisis ...
# 151       2024-06-04  aumentan las pérdidas y el vix sube hacia 15 |...
# 152       2024-06-04  de la mano: educación financiera y qué está pa...
# 153       2024-06-04  bitcoin: entiende ésto y ganarás | btc | crypt...
# 154       2024-06-05  la guerra comercial entre ee.uu. y china expli...
# 155       2024-06-05           bitcoin: gane cuándo pueda| crypto | btc
# 156       2024-06-05  qué hará bitcoin hoy  05/06/24 08:00 análisis ...
# 157       2024-06-05  herramientas de sentimiento que te ayudan a co...
# 158       2024-06-05            ¿sube o baja el dolar en colombia 2024?
# 159       2024-06-05  ruido de mercado: subidas por empleo privado y...
# 160       2024-06-05  bitcoin: ilusionando para caer | btc | cryptos...
# 162       2024-06-06  ¡bolsas en alza! ¿podrán mantenerse a pesar de...
# 163       2024-06-06  qué hará bitcoin hoy  06/06/24 08:00 análisis ...
# 165       2024-06-07             bitcoin: estás asustado?| crypto | btc
# 166       2024-06-07  qué hará bitcoin hoy  07/06/24 08:00 análisis ...
# 167       2024-06-07   así van las 7 acciones "magnificas" escogidas...
# 168       2024-06-07  estrategia tendencial:  un etf que te va a int...
# 169       2024-06-07  acción del precio en bitcoin hoy deja claras s...
# 170       2024-06-07  bitcoin: urgente, debes ver ésto | btc | crypt...
# 172       2024-06-08     qué acciones y etfs negociar la próxima semana
# 173       2024-06-08   venden bitcoin en el doble objetivo de $71k y...
# 176       2024-06-10  así va la cartera modelo y valorando nuevas co...
# 177       2024-06-10  qué hará bitcoin hoy  10/06/24 08:00 análisis ...
# 178       2024-06-10  bitcoin: patrón de caída en gráfico diario \ b...
# 180       2024-06-11  chatgpt + apple: la combinación que impulsarán...
# 181       2024-06-11  qué hará bitcoin hoy  11/06/24 08:00 análisis ...
# 182       2024-06-11  se cumple la proyección de apple y va a por ob...
# 183       2024-06-11  mañana será decisivo para btc y bolsas pero en...
# 185       2024-06-12   ¿por qué tesla está colapsando en bolsa?  ¿es...
# 186       2024-06-12  bitcoin: sabes cómo hacer la encerrona? | cryp...
# 187       2024-06-12  ojo al sentimiento del mercado, fed influirá e...
# 188       2024-06-12  qué hará bitcoin hoy  12/06/24 08:00 análisis ...
# 189       2024-06-12  euforia tras conocerse el ipc de usa pero falt...
# 191       2024-06-12  bitcoin: perdieron todo | btc | cryptos | etf ...
#
#                                                   text  year
# 141  en qué invertir desde junio en las bolsas prem...  2024
# 143  bitcoin: te concentras o pierdes el último coh...  2024
# 144  bolsas hoy: amd presentó nuevo procesador ia p...  2024
# 145  qué hará bitcoin hoy 03/06/24 08:00 análisis t...  2024
# 146  junio primera confirmación vendedora ¡qué pode...  2024
# 147  ruido y trampas hoy qué esperamos de bitcoin c...  2024
# 148  bitcoin: camino al matadero | btc | cryptos | ...  2024
# 150  qué hará bitcoin hoy 04/06/24 08:00 análisis t...  2024
# 151  aumentan las pérdidas y el vix sube hacia 15 |...  2024
# 152  de la mano: educación financiera y qué está pa...  2024
# 153  bitcoin: entiende ésto y ganarás | btc | crypt...  2024
# 154  la guerra comercial entre ee.uu. y china expli...  2024
# 155  bitcoin: gane cuándo pueda| crypto | btc. en c...  2024
# 156  qué hará bitcoin hoy 05/06/24 08:00 análisis t...  2024
# 157  herramientas de sentimiento que te ayudan a co...  2024
# 158  ¿sube o baja el dolar en colombia 2024?. [músi...  2024
# 159  ruido de mercado: subidas por empleo privado y...  2024
# 160  bitcoin: ilusionando para caer | btc | cryptos...  2024
# 162  ¡bolsas en alza! ¿podrán mantenerse a pesar de...  2024
# 163  qué hará bitcoin hoy 06/06/24 08:00 análisis t...  2024
# 165  bitcoin: estás asustado?| crypto | btc. el fó ...  2024
# 166  qué hará bitcoin hoy 07/06/24 08:00 análisis t...  2024
# 167  así van las 7 acciones "magnificas" escogidas ...  2024
# 168  estrategia tendencial: un etf que te va a inte...  2024
# 169  acción del precio en bitcoin hoy deja claras s...  2024
# 170  bitcoin: urgente, debes ver ésto | btc | crypt...  2024
# 172  qué acciones y etfs negociar la próxima semana...  2024
# 173  venden bitcoin en el doble objetivo de $71k y ...  2024
# 176  así va la cartera modelo y valorando nuevas co...  2024
# 177  qué hará bitcoin hoy 10/06/24 08:00 análisis t...  2024
# 178  bitcoin: patrón de caída en gráfico diario \ b...  2024
# 180  chatgpt + apple: la combinación que impulsarán...  2024
# 181  qué hará bitcoin hoy 11/06/24 08:00 análisis t...  2024
# 182  se cumple la proyección de apple y va a por ob...  2024
# 183  mañana será decisivo para btc y bolsas pero en...  2024
# 185  ¿por qué tesla está colapsando en bolsa? ¿es u...  2024
# 186  bitcoin: sabes cómo hacer la encerrona? | cryp...  2024
# 187  ojo al sentimiento del mercado, fed influirá e...  2024
# 188  qué hará bitcoin hoy 12/06/24 08:00 análisis t...  2024
# 189  euforia tras conocerse el ipc de usa pero falt...  2024
# 191  bitcoin: perdieron todo | btc | cryptos | etf ...  2024

# %% [markdown]
# ## store documents

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from external.lang_chain_manager import LangChainManager
from external.pinecone_vdb import PineconeVectorDB
from app.repositories.pinecone_vdb_loader import PinceconeVDBRepository
from app.use_cases.clean_vector_data_base import CleanVectoreStore
from app.use_cases.data_to_vector_data_base import LoadDataVectoreStore

# %%
langchain_manager = LangChainManager()
pinecone_vdb = PineconeVectorDB()
vdb_repository= PinceconeVDBRepository(pinecone_vdb,langchain_manager)
load_vdb_use_case = LoadDataVectoreStore(vdb_repository)
clean_vdb_use_case = CleanVectoreStore(vdb_repository)

# %%
clean_vdb_use_case.execute()

# %%
langchain_manager.embedding.azure_endpoint
# Out:
# 'https://openai-eafit-proyecto.openai.azure.com/'

# %%
docs =load_vdb_use_case.execute(df_curated[df_curated['publish_date']=='2024-06-01'],id_column="video_id",chunk_size=250,chunk_overlap=0)
